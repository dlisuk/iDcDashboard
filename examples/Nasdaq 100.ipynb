# %%
import sys
sys.path.append('../')


from __future__ import print_function # For py 2.7 compat

import dc_dashboard
from dc_dashboard import *
import pandas as pd
# Out:
# <style>    .document{
#         padding: 5px;
#         margin:  5px;
#         width: 100%;
#         clear:both;
#     }
#     .layer{
#         padding: 5px;
#         margin:  5px;
#         width: 100%;
#         clear:both;
#     }
#     .title{
#         font-weight: bold;
#     }
#     .plot_parent{
#         float:left;
#     }
#
#     th {
#         border: 1px solid #000;
#     }
#     tr td {
#         border: 1px solid #000;
#     }
#
#     tr.oddrow td {
#         border: 1px solid #F00;
#
#     }
#
#     tr:nth-child(even) {background: #CCC}
#     tr:nth-child(odd) {background: #FFF}
#
# </style><link rel="stylesheet" type="text/css" href="http://cdnjs.cloudflare.com/ajax/libs/dc/2.0.0-alpha.2/dc.css">

# %%
data = pd.read_csv("http://dc-js.github.io/dc.js/ndx.csv")

# %% [markdown]
# Here we create a simple dashboard we use python to add some fields, but there are some fields which are easier to compute client side, so we use the preproc function.

# %%
import time
data["gl"] = ["Gain" if x > 0 else "Loss" for x in (data.close-data.open)]
data["year"] = [int(x.split('/')[2]) for x in data.date]
data["quarter"] = [(int(x.split('/')[0])-1)/3+1 for x in data.date]
data["TimeStamp"] = [time.mktime(time.strptime(x, "%m/%d/%Y")) for x in data["date"]]

# %%
data.head()
# Out:
#          date    open    high     low   close  volume  oi    gl  year  \
# 0  11/01/1985  115.48  116.78  115.48  116.28  900900   0  Gain  1985
# 1  11/04/1985  116.28  117.07  115.82  116.04  753400   0  Loss  1985
# 2  11/05/1985  116.04  116.57  115.88  116.44  876800   0  Gain  1985
# 3  11/06/1985  116.44  117.62  116.44  117.38  935000   0  Gain  1985
# 4  11/07/1985  117.38  117.96  117.38  117.62  886400   0  Gain  1985
#
#    quarter  TimeStamp
# 0        4  499680000
# 1        4  499939200
# 2        4  500025600
# 3        4  500112000
# 4        4  500198400
#
# [5 rows x 11 columns]

# %%
dashboard = Dashboard(
    Backend.DF_Backend(data),
    [
        Dimension("gl"),
        Dimension("quarter"),
        Dimension("year"),
        Dimension("open","close").add_group("hundreds", 
                                            Group("function(d){return Math.floor(d[0]/100);}").reduce_sum("close")),
        Dimension("TimeStamp").add_group("close", Group().reduce_count())
    ],
    [
        Layer(200),
        Plot("pie").data_source("gl").title("Gain or Loss"),
        Plot("pie").data_source("quarter").title("Quarter"),
        Plot("bar").data_source("year").title("Year").width(400),
        Layer(250),
        Plot("line").data_source("TimeStamp","close").title("Close").width(800)
    ]
)
dashboard.show()
